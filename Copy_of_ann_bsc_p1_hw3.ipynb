# %% [markdown]
# # 3. házi feladat
#
# **Mese:** László gazda állatokat tenyészt. Sok a problémája az elkószáló jószággal, ezért a gépi tanulás eszközeihez folyamodna. Szeretne a birtoka határán kamerákat felállítani és azok képén detektálni az elkóboroló állatot. Nem pusztán azt kellene megmondani, hogy van-e állat a képen, hanem, azt is, hogy a kép melyik részén van, hiszen innen tudja majd a gazda, hogy túljutott-e az állat a villanypásztoron, vagy sem.
#
# László gazda, a helyi művelődési ház legutóbbi, "Webre, Nagyi!" tanfolyamának óráján hallott a konvolúciós hálókról és a képszegmentációról. Úgy gondolja, ezekkel az eszközökkel meg tudná oldani a problémáját. A tanfolyamról tudja azt is, hogy a gépi tanulás alkalmazásához általában sok címkézett adat kell. Éppen ezért nekiállt már korábban, - saját számítógépe nem lévén - a városi könyvtár egyik gépén, állatos és egyéb képeket letöltögetni az internetről és megcímkézni őket aszerint, hogy mi látható rajtuk. Viszonylag sok képet sikerült összegyűjtenie, de a gazda hamar rájött, hogy képszegmentációhoz másfajta címkézés szükséges: körül kell rajzolnia az állatokat a képen. Neki is állt, azonban egyre több gúnyos megjegyzést kapott, amint a könyvtárban rendre azon kapták, hogy egészen közel hajolva a monitorhoz birkákat és lábasjószágot vizslat. A szégyentől menekülvén, hamarosan le is állt az akciójával. Sajnos csak néhány tucat állatot sikerült körülrajzolnia. Felhívja unokáját (Téged), hátha tud neki segíteni. Rájössz, hogy a transfer learning megoldást nyújthat a gazda problémájára: a sok kategóriacímkés képen betanítasz egy konvolúciós hálót klasszifikációra, majd a gazda által körülrajzolt kevés képen finomhangolod azt, hogy képes legyen kiszegmentálni az állatot a képről. Hogy megmutasd mennyire egyszerű feladatot kér tőled a gazda, vállalod, hogy csavarsz egyet a problémán: a kiszegmentálandó állatfajról az előtanítás során a háló nem lát képeket.
#
# _~ Vége ~_
#
# **Feldat:** A harmadik házi feladat során először egy konvolúciós hálót kell betanítani képek multiclass klasszifikációjára. A betanított modellt felhasználva alapként, egy fully-convolutional network (FCN) hálót kell építeni, majd betanítani egy megadott kategória szerinti bináris képszegmentálási feladatra. A szegmentáláshoz használt kategóriát a klasszifikációs előtanítás során a háló nem láthatja.
#
# A házi feladat több részfeladatból áll (A - Q), melyek egymásra épülnek. A B, G, K és O részfeladatokból több változat van: ezekből mindenkinek egyet-egyet kell megoldania. **Arról, hogy ki melyiket oldja meg, az alábbi linken található lista ad tájékoztatást** Neptun-kód - feladatok listája formában:
#
# https://drive.google.com/open?id=1mUDkeKS3ZgL6KkJeAEkP_n7vl0WUZi_V
#
# A feladat automatikus tesztelőszkripttel rendelkezik. Éppen ezért, **ne változtasd meg a notebook struktúráját**, ne szedd több részre, illetve ne módosítsd a megírt részeket, csak a megoldásaidat írd be a megfelelő helyre, különben nem fogjuk tudni értékelni. A megoldások az `# Implement your solution BELOW` és `# Implement your solution ABOVE` sorok közé írandók. Ha a megoldott részfeladatok futtatásakor a "Tester: .... OK" felirat megjelenik, _feltehetően_ jó a megoldás. A beadott házifeladatok másolásellenőrzésen esnek át. Közösen megoldott feladat esetén, csak az egyik hallgató kaphatja meg a jegyet. (A hallgatók dönthetik el egymás között.)
#
# **!!! A feladatok megoldását, vagy az arra mutató linkeket bárhol közzétenni tilos !!!**
#
# Elakadás esetén Canvas fórumon kérhető és nyújtható segítség, de legfeljebb olyan jellegű válasz adható hallgatói részről, hogy melyik függvényt érdemes megpróbálni, vagy például egy hasonló példához hogyan kellene a tömböt indexelni. **Akár kérdésben, akár válaszban a megoldás jelentős részét tartalmazó kódrészletet közzétenni tilos.**
#
# **Megoldás és beküldés menete:**
#
# A közzétett, feladatokat tartalmazó Google Colab notebook csak "view" jogosultságokkal van megosztva. Mindenkinek le kell másolnia a saját Drive-jára a notebook-ot (Google Colab file menü -> Save a copy to Drive): a másolat már szerkeszthető és futtatható lesz. **A kész megoldást tartalmazó notebook-ot le kell tölteni**  (Google Colab file menü -> Download .ipynb), **majd a Canvas-ban, a kiírt feladatnál feltölteni.** Link nem adható be, csak az .ipynb fájl. A futtatási eredményeket (kiírt szövegeket, kirajzolt plotokat) lehetőleg hagyd a notebookban amikor beadod azt.
#
# **Határidő:** 2020. május 20., szerda, 23:59.
#
# **Pontozás:** A házi feladat helyes megoldása feltétele a jegyszerzésnek. Az, aki az első határidőig helyes megoldást küldd be, 2 pontot kap, ami a félév végi vizsga pontszámához adódik, amennyiben az elégséges szintet a vizsga eléri (a vizsgán várhatóan 10-10 pont szükséges a végső érdemjegy eggyel történő javításához). Az első határidő után körülbelül még két hét fog rendelkezésre állni a házi feladat leadására, immár pluszpont nélkül.
#
# Törekedj arra, hogy ciklust és hasonló konstrukciókat csak ott használj, ahol nélkülözhetetlen, vagy ahol csak kis számú iteráció történik ilyen módon. Mindenhol máshol, törekedj a Numpy-os, vektorizált megoldásra.
#
# **GPU használata Google Colab-ban:** A konvolúciós háló betanítása több erőforrást igényel, így érdemes a betanításhoz bekapcsolni a GPU gyorsítást. *Edit -> Notebook settings -> Hardware accelerator: GPU*
#
# A betanításon kívüli fejlesztési fázisban előnyös lehet a GPU gyorsítást kikapcsolni, ugyanis a Google az erőforrások kiosztásánál, saját bevallása szerint, azokat a felhasználókat részesíti előnyben, akik nem használnak GPU-t rendszeresen, sok órán át, vagy nem hagynak csatlakoztatott GPU-s futtatókörnyezetet sokáig kihasználatlanul. A H és P kódblokkokon kívül semelyik másik feladatnál nem ad előnyt a GPU gyorsítás. _"To avoid hitting your GPU usage limits, we recommend switching to a standard runtime if you are not utilizing the GPU."_ (A usage limit nem nyilvános és dinamikusan van meghatározva. Néhány órányi használat nem valószínű, hogy kimeríti.) A GPU ki- és bekapcsolásakor a futtatókörnyezethez rendelt tárhely tipikusan megváltozik!

# %% [markdown]
# Tesztelő szkript letöltése, importok.

# %%
# Download tester
# !rm hw3_tester.py
# !wget http://nipg12.inf.elte.hu:800/vavsaai/annbsc_p1_hw3/hw3_tester.py

import os
import pickle

import matplotlib.pyplot as plt
import numpy as np

# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Conv2D, Dropout, MaxPooling2D, Flatten, Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow.keras.optimizers

# import tester after importing tensorflow, to make sure correct tf version is imported
from hw3_tester import Tester
# Out:
# rm: cannot remove 'hw3_tester.py': No such file or directory
# --2020-06-22 14:07:36--  http://nipg12.inf.elte.hu:800/vavsaai/annbsc_p1_hw3/hw3_tester.py
# Resolving nipg12.inf.elte.hu (nipg12.inf.elte.hu)... 157.181.160.172
# Connecting to nipg12.inf.elte.hu (nipg12.inf.elte.hu)|157.181.160.172|:800... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24018 (23K) [text/x-python]
# Saving to: ‘hw3_tester.py’
#
# hw3_tester.py       100%[===================>]  23.46K  87.3KB/s    in 0.3s
#
# 2020-06-22 14:07:37 (87.3 KB/s) - ‘hw3_tester.py’ saved [24018/24018]

# %% [markdown]
# A tesztelőszkript a részedre kiosztott feladatok helyességét fogja tesztelni. Ehhez az alábbi kódblokkban, a Tester példányosításakor, paraméterként a Neptun-kódodat kell megadni egy sztringként, pl:
# `tester = Tester('DK7UAQ')`, majd futtatni kell a blokkot.

# %%
tester = Tester('X4YWL8')

# %% [markdown]
# Letöltjük az előfeldolgozott adatbázist, ha nem található meg a futtatókörnyezet tárhelyén. A képeket tartalmazó fájlok együttes mérete 400 megabájt körüli, 1-2 percet igénybe vehet a letöltése a futtatókörnyezet tárhelyére. Előfordul, hogy a tárhelyen elérhetők maradnak a fájlok akkor is, ha a futtatókörnyezetről lekapcsolódunk, de ez nem garantált.

# %%
# !wget -nc -P VOC2012/ http://nipg12.inf.elte.hu:800/vavsaai/annbsc_p1_hw3/VOC2012/class_data.pkl
# !wget -nc -P VOC2012/ http://nipg12.inf.elte.hu:800/vavsaai/annbsc_p1_hw3/VOC2012/class_label.pkl
# !wget -nc -P VOC2012/ http://nipg12.inf.elte.hu:800/vavsaai/annbsc_p1_hw3/VOC2012/seg_data.pkl
# !wget -nc -P VOC2012/ http://nipg12.inf.elte.hu:800/vavsaai/annbsc_p1_hw3/VOC2012/seg_label.pkl
# Out:
# --2020-06-22 14:07:49--  http://nipg12.inf.elte.hu:800/vavsaai/annbsc_p1_hw3/VOC2012/class_data.pkl
# Resolving nipg12.inf.elte.hu (nipg12.inf.elte.hu)... 157.181.160.172
# Connecting to nipg12.inf.elte.hu (nipg12.inf.elte.hu)|157.181.160.172|:800... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 326271136 (311M)
# Saving to: ‘VOC2012/class_data.pkl’
#
# class_data.pkl      100%[===================>] 311.16M  3.56MB/s    in 88s
#
# 2020-06-22 14:09:18 (3.53 MB/s) - ‘VOC2012/class_data.pkl’ saved [326271136/326271136]
#
# --2020-06-22 14:09:20--  http://nipg12.inf.elte.hu:800/vavsaai/annbsc_p1_hw3/VOC2012/class_label.pkl
# Resolving nipg12.inf.elte.hu (nipg12.inf.elte.hu)... 157.181.160.172
# Connecting to nipg12.inf.elte.hu (nipg12.inf.elte.hu)|157.181.160.172|:800... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66535 (65K)
# Saving to: ‘VOC2012/class_label.pkl’
#
# class_label.pkl     100%[===================>]  64.98K   121KB/s    in 0.5s
#
# 2020-06-22 14:09:21 (121 KB/s) - ‘VOC2012/class_label.pkl’ saved [66535/66535]
#
# --2020-06-22 14:09:23--  http://nipg12.inf.elte.hu:800/vavsaai/annbsc_p1_hw3/VOC2012/seg_data.pkl
# Resolving nipg12.inf.elte.hu (nipg12.inf.elte.hu)... 157.181.160.172
# Connecting to nipg12.inf.elte.hu (nipg12.inf.elte.hu)|157.181.160.172|:800... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85278880 (81M)
# Saving to: ‘VOC2012/seg_data.pkl’
#
# seg_data.pkl        100%[===================>]  81.33M  3.79MB/s    in 23s
#
# 2020-06-22 14:09:47 (3.54 MB/s) - ‘VOC2012/seg_data.pkl’ saved [85278880/85278880]
#
# --2020-06-22 14:09:48--  http://nipg12.inf.elte.hu:800/vavsaai/annbsc_p1_hw3/VOC2012/seg_label.pkl
# Resolving nipg12.inf.elte.hu (nipg12.inf.elte.hu)... 157.181.160.172
# Connecting to nipg12.inf.elte.hu (nipg12.inf.elte.hu)|157.181.160.172|:800... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28426397 (27M)
# Saving to: ‘VOC2012/seg_label.pkl’
#
# seg_label.pkl       100%[===================>]  27.11M  3.70MB/s    in 8.7s
#
# 2020-06-22 14:09:58 (3.10 MB/s) - ‘VOC2012/seg_label.pkl’ saved [28426397/28426397]

# %% [markdown]
# Az adatbázis beolvasása.

# %%
CAT_NAMES = ['aeroplane', 'bird', 'boat', 'bus', 'car', 'cat', 'cow', 'dog', 'horse', 'sheep']

with open('VOC2012/class_data.pkl', 'rb') as f:
    arr_cl_data = pickle.load(f)
with open('VOC2012/class_label.pkl', 'rb') as f:
    arr_cl_labs = pickle.load(f)
with open('VOC2012/seg_data.pkl', 'rb') as f:
    arr_seg_data = pickle.load(f)
with open('VOC2012/seg_label.pkl', 'rb') as f:
    arr_seg_labs = pickle.load(f)
    
print("Shape of classification image array:", arr_cl_data.shape)
print("Shape of classification label array:", arr_cl_labs.shape)
print("Shape of segmentation image array:", arr_seg_data.shape)
print("Shape of segmentation label array:", arr_seg_labs.shape)
# Out:
# Shape of classification image array: (6638, 128, 128, 3)
# Shape of classification label array: (6638, 10)
# Shape of segmentation image array: (1735, 128, 128, 3)
# Shape of segmentation label array: (1735, 128, 128)

# %% [markdown]
# Az `arr_cl_data` tömb alakja (n_cl_images, size_y, size_x, n_channels=3), a klasszifikációhoz használandó RGB kódolású képeket tartalmazza 10 kategóriából válogatva. Az `arr_cl_labs` címketömb az ezeken a képeken megtalálható objektumok kategória-azonosítóit tartalmazza. Alakja (n_cl_images, n_categories=10). Minden képre 10 darab számot tárol (nullát, vagy egyet), aszerint, hogy az adott kategóriájú objektum előfordul-e a képen. Egy képen többféle objektum is megtalálható lehet, ekkor nyilván több egyes számjegy van a címketömb adott képhez tartozó sorában.
#
# Az `arr_seg_data` tömb az `arr_cl_data` tömbhöz hasonló formátumú, de jóval kevesebb kép van benne, alakja (n_seg_images, size_y, size_x, n_channels=3). Ezekhez a képekhez pixel szintű annotáció is tartozik, ami az `arr_seg_labs` tömbben van eltárolva, így szegmentálás betanításához használhatók. A `arr_seg_labs` tömb alakja (n_seg_images, size_y, size_x). Minden pixelre egy `uint8` típusú számot tárol, ami a következő lehet: 0 - háttér, 1 .. 10 - valamelyik kategória a 10 közül, 255 - kategóriák közti határvonal.
#
# Érdemes odafigyelni a kategóriák azonosítóinál: a klasszifikációs címketömbben az egyes kategóriák a 0-tól 9-es indexeken vannak (lévén 10 hosszú a tengely), míg a szegmentációs címkék pixelei ugyanezeket a kategóriákat 1-től 10-es értékekkel kódolják.

# %% [markdown]
# ###**A**: Képek kirajzolása a klasszifikációs adatbázisból
#
# Elsőként belenézünk a letöltött klasszifikációs adatbázis tartalmába. Rajzolj ki néhány képet az `arr_cl_data` tömbből és írd ki az adott kép kategóriájának nevét a kirajzolt képek alá/fölé! A kategórianevek az előző kód blokkban a `CAT_NAMES` listában meg lettek adva.

# %%
# implement your solution BELOW

sample_idxs = np.random.choice(arr_cl_data.shape[0], size=12)

fig, axs = plt.subplots(2, 6)
fig.set_figheight(6)
fig.set_figwidth(14)
for plot_idx in range(12):
    axs[plot_idx//6, plot_idx%6].imshow(arr_cl_data[sample_idxs[plot_idx]])
    axs[plot_idx//6, plot_idx%6].axis('off')
    text = str(arr_cl_labs[sample_idxs[plot_idx],:])
    axs[plot_idx//6, plot_idx%6].set_title(text)


# implement your solution ABOVE

# %% [markdown]
# ###**B**: Új kategóriák definiálása a klasszifikációhoz
#
# Mivel háziállatokat szeretnénk tudni felismerni/szegmentálni, a multi-class klasszifikációban ezekre a kategóriákra fogunk koncentrálni. A klasszifikációs feladatban öt kategória egyikébe kell a képeinket megtanulni besorolni. A háziállat kategóriákat megtanuljuk elkülöníteni egymástól, a fennmaradó kategóriákat "egyéb/other" címen egy kategóriába soroljuk. A klasszifikációhoz elkülönítendő öt kategória tehát a következő:
#
# - **B/1**: [{'aeroplane', 'bird', 'boat', 'bus', 'car'}, 'cat', 'dog', 'horse', 'sheep']
# - **B/2**: [{'aeroplane', 'bird', 'boat', 'bus', 'car'}, 'cat', 'cow', 'dog', 'sheep']
# - **B/3**: [{'aeroplane', 'bird', 'boat', 'bus', 'car'}, 'cat', 'cow', 'dog', 'horse']
#
# (A szegmentációs feladatban majd mindenkinek az egyetlen kimaradt háziállat kategóriát kell tudnia tanulni szegmentálni, az összes másik és a háttér ellenében.)
#
# Készítsd el a `sample_idxs_ls` listát! A lista legyen 5 hosszú, az elemei a fent megjelölt új kategóriában megtalálható képek/címkék index-tömbjei. Az index tömbök elemei az `arr_cl_data` és `arr_cl_labs` tömbökből a megfelelő kategóriájú elemeket hivatkozzák. Például, a lista első eleme az {'aeroplane', 'bird', 'boat', 'bus', 'car'} kategóriák egyikébe tartozó képek indexeit tartalmazó tömb. A második eleme a 'cat' kategóriába tartozó képek indexeit tartalmazó tömb, stb. Csak azoknak a képeknek az indexeit válogasd be a `sample_idxs_ls` listába, amelyeken pontosan egy kategória szerepel! Azokat a képeket, melyeken több kategória szerepel egyszerre, nem fogjuk felhasználni a klasszifikációs feladatban.
#
# Mivel a háziállatoknál gyakori képi mintázatokat szeretnénk a leginkább megtanulni felismerni, ezért szükséges, hogy a betanításhoz használt adatbázis elemei közt a háziállatok legyenek többségben. Az első 'egyéb' kategória az adatbázisunkban felülreprezentált, túl sok elem esik ebbe a kategóriába, így ezeknek csak egy részét tartjuk meg. Válassz **véletlenszerűen** 1000 indexet az első 'egyéb' kategória indexei közül és csak ezek kerüljenek bele a `sample_idxs_ls[0]` tömbbe!

# %%
# implement your solution BELOW

CATEGORY_IDX_OTHER_PLANE = 0
CATEGORY_IDX_OTHER_BIRD = 1
CATEGORY_IDX_OTHER_BOAT = 2
CATEGORY_IDX_OTHER_BUS = 3
CATEGORY_IDX_OTHER_CAR = 4
CATEGORY_IDX_CAT = 5
CATEGORY_IDX_COW = 6
CATEGORY_IDX_DOG = 7
CATEGORY_IDX_HORSE = 8
CATEGORY_IDX_SHEEP = 9

good_imgs_mask = np.sum(arr_cl_labs[:,[CATEGORY_IDX_OTHER_PLANE,CATEGORY_IDX_OTHER_BIRD, CATEGORY_IDX_OTHER_BOAT,
                                       CATEGORY_IDX_OTHER_BUS, CATEGORY_IDX_OTHER_CAR, CATEGORY_IDX_CAT, CATEGORY_IDX_COW,
                                       CATEGORY_IDX_DOG, CATEGORY_IDX_HORSE, CATEGORY_IDX_SHEEP]], axis=1) == 1

sample_idxs = np.where(good_imgs_mask)[0]
sample_idxs_ls = []

others_planes = np.zeros((sample_idxs.shape[0],), dtype=np.int32)
planes_mask = arr_cl_labs[sample_idxs, CATEGORY_IDX_OTHER_PLANE] == 1
others_planes[planes_mask] = 1
other_planes_indxs = np.nonzero(others_planes)[0]

others_birds = np.zeros((sample_idxs.shape[0],), dtype=np.int32)
birds_mask = arr_cl_labs[sample_idxs, CATEGORY_IDX_OTHER_BIRD] == 1
others_birds[birds_mask] = 1
other_birds_indxs = np.nonzero(others_birds)[0]

others_boats = np.zeros((sample_idxs.shape[0],), dtype=np.int32)
boats_mask = arr_cl_labs[sample_idxs, CATEGORY_IDX_OTHER_BOAT] == 1
others_boats[boats_mask] = 1
other_boats_indxs = np.nonzero(others_boats)[0]

others_buses = np.zeros((sample_idxs.shape[0],), dtype=np.int32)
buses_mask = arr_cl_labs[sample_idxs, CATEGORY_IDX_OTHER_BUS] == 1
others_buses[buses_mask] = 1
other_buses_indxs = np.nonzero(others_buses)[0]

others_cars = np.zeros((sample_idxs.shape[0],), dtype=np.int32)
cars_mask = arr_cl_labs[sample_idxs, CATEGORY_IDX_OTHER_CAR] == 1
others_cars[cars_mask] = 1
other_cars_indxs = np.nonzero(others_cars)[0]

other_indxs = np.concatenate([other_planes_indxs, other_birds_indxs,other_boats_indxs,other_buses_indxs,other_cars_indxs])

sample_other_indxs = np.random.choice(other_indxs, size=1000)
sample_other_indxs = np.sort(sample_other_indxs)
sample_idxs_ls.append(sample_other_indxs)

cats = np.zeros((sample_idxs.shape[0],), dtype=np.int32)
cats_mask = arr_cl_labs[sample_idxs, CATEGORY_IDX_CAT] == 1
cats[cats_mask] = 1
cats_indxs = np.nonzero(cats)[0]
sample_idxs_ls.append(cats_indxs)

dogs = np.zeros((sample_idxs.shape[0],), dtype=np.int32)
dogs_mask = arr_cl_labs[sample_idxs, CATEGORY_IDX_DOG] == 1
dogs[dogs_mask] = 1
dogs_indxs = np.nonzero(dogs)[0]
sample_idxs_ls.append(dogs_indxs)

horses = np.zeros((sample_idxs.shape[0],), dtype=np.int32)
horses_mask = arr_cl_labs[sample_idxs, CATEGORY_IDX_HORSE] == 1
horses[horses_mask] = 1
horses_indxs = np.nonzero(horses)[0]
sample_idxs_ls.append(horses_indxs)

sheeps = np.zeros((sample_idxs.shape[0],), dtype=np.int32)
sheeps_mask = arr_cl_labs[sample_idxs, CATEGORY_IDX_SHEEP] == 1
sheeps[sheeps_mask] = 1
sheeps_indxs = np.nonzero(sheeps)[0]
sample_idxs_ls.append(sheeps_indxs)

# implement your solution ABOVE

print("Category shapes:", [cat_samples.shape for cat_samples in sample_idxs_ls])

tester.test('cl_categories', sample_idxs_ls)
# Out:
# Category shapes: [(1000,), (1043,), (1204,), (454,), (301,)]
# Tester: Classifier new categories OK

# %% [markdown]
# ###**C**: A klasszifikációhoz felhasználandó adatok kiválogatása
# A `sample_idxs_ls` tömbök listájában előállítottuk, hogy melyik kategóriába melyik képek/címkék tartoznak az eredeti (`arr_cl_data` és `arr_cl_labs`) tömbökből. Az előállított indextömböket az `arr_cl_data` és `arr_cl_labs` tömbök indexelésére használva készítsd el a képeket és címkéket tartalmazó `xs` és `ys` tömböket, ahol `xs` alakja (n_cl_good_images, size_y, size_x, n_channels=3) és `ys` alakja (n_cl_good_images,). Utóbbi az új kategóriák indexeit tartalmazza ('other' esetén 0, 'cat' esetén 1, stb.)!
#
# (Itt "n_cl_good_images" a `sample_idxs_ls`-beli tömbök hosszának összege, azaz a felhasznált képek száma az összes kategóriából.)

# %%
# implement your solution BELOW


xs =np.concatenate([arr_cl_data[sample_idxs[sample_idxs_ls[0]]],
                    arr_cl_data[sample_idxs[sample_idxs_ls[1]]],
                    arr_cl_data[sample_idxs[sample_idxs_ls[2]]],
                    arr_cl_data[sample_idxs[sample_idxs_ls[3]]],
                    arr_cl_data[sample_idxs[sample_idxs_ls[4]]]])

ys =np.concatenate([np.ones((sample_idxs_ls[0].shape[0],),dtype=np.int32)*0,
                    np.ones((sample_idxs_ls[1].shape[0],),dtype=np.int32)*1,
                    np.ones((sample_idxs_ls[2].shape[0],),dtype=np.int32)*2,
                    np.ones((sample_idxs_ls[3].shape[0],),dtype=np.int32)*3,
                    np.ones((sample_idxs_ls[4].shape[0],),dtype=np.int32)*4])

# implement your solution ABOVE

tester.test('cl_dataset_creation', xs, ys)
# Out:
# Tester: Classifier dataset OK

# %% [markdown]
# ###**D**: Keverés, normalizálás és felbontás tanító-, validációs- és teszthalmazra
#
# - Keverjük meg konzisztensen a képeket (`xs`) és a kategóriacímkéket (`ys`). Ez szükséges, hiszen a két tömböt valószínűleg úgy állítottuk elő az előző kódblokkban, hogy a kategóriacímkék sorban következnek egymás után, így a tanító-, validációs- és teszthalmazra való felbontásnál előfordulna olyan kategória, amelyik csak az egyik halamzban lenne jelen.
# - Mivel az input változók nagyságrendje azonos (0..255), így ezúttal nem fogjuk a hagyományos változónként független min-max/mean-std skálázást használni. Azonban, ahogy az a konvolúciós hálós segédanyag notebookban részletezve van, érdemes az inputokat 0 közepűre és +- 1 nagyságrendre hozni. Lineárisan skálázva transzformáljuk a [0,255] intervallumon található pixelértékeket [-1,1] intervallumra. A skálázás előtt szükséges az eredetileg `uint8` típusú pixelértékeket lebegőpontossá (`float32`) konvertálni.
# - Bontsuk fel tanító-, validációs- és teszthalmazra a két tömböt. Használjunk 60%/20%/20%-os felosztást. Állítsuk elő így az `x_train`, `x_val`, `x_test` inputokat (képeket) és `y_train`, `y_val`, `y_test` címkéket tartalmazó tömböket!

# %%
# implement your solution BELOW

shuffler = np.random.permutation(xs.shape[0])
xs = xs[shuffler,:,:,:]
ys = ys[shuffler]

val_offset = int(xs.shape[0]*0.6)
test_offset = int(xs.shape[0]*0.8)

x_train_unnormed = xs[:val_offset]
x_val_unnormed = xs[val_offset:test_offset]
x_test_unnormed = xs[test_offset:]
y_train_unnormed = ys[:val_offset]
y_val_unnormed = ys[val_offset:test_offset]
y_test_unnormed = ys[test_offset:]

x_train = x_train_unnormed.astype(np.float32)/127.5 - 1.
x_val = x_val_unnormed.astype(np.float32)/127.5 - 1.
x_test = x_test_unnormed.astype(np.float32)/127.5 - 1.
y_train = y_train_unnormed.astype(np.float32)
y_val = y_val_unnormed.astype(np.float32)
y_test = y_test_unnormed.astype(np.float32)

# implement your solution ABOVE

print("Training set shapes:", x_train.shape, y_train.shape)
print("Validation set shapes:", x_val.shape, y_val.shape)
print("Test set shapes:", x_test.shape, y_test.shape)

tester.test('cl_dataset_split', x_train, x_val, x_test, y_train, y_val, y_test)
# Out:
# Training set shapes: (2401, 128, 128, 3) (2401,)
# Validation set shapes: (800, 128, 128, 3) (800,)
# Test set shapes: (801, 128, 128, 3) (801,)
# Tester: Classifier dataset split OK

# %% [markdown]
# ###**E**: Véletlen választott kép-címke párok kirajzolása/kiírása
#
# Győződj meg róla, hogy nem történt-e a keverés során hiba és továbbra is minden képhez megfelelő (új kategória-felosztás szerinti) címke tartozik.
#
# Rajzolj ki néhány **véletlenszerűen választott** képet az `x_train`, `x_val`, `x_test` tömbök egyikéből és írasd ki a képek alatt/felett a képekhez tartozó új kategória indexét (0, 1, 2, 3, vagy 4)!

# %%
# implement your solution BELOW

sample_idxs = np.random.choice(x_train.shape[0], size=12)

fig, axs = plt.subplots(2, 6)
fig.set_figheight(6)
fig.set_figwidth(14)
for plot_idx in range(12):
    axs[plot_idx//6, plot_idx%6].imshow(x_train[sample_idxs[plot_idx]]*0.5 + 0.5)
    axs[plot_idx//6, plot_idx%6].axis('off')
    axs[plot_idx//6, plot_idx%6].set_title("y: " + str(y_train[sample_idxs[plot_idx]]))


# implement your solution ABOVE

# %% [markdown]
# ###**F**: Konvolúciós háló definiálása klasszifikációhoz
#
# Definiálj egy konvolúciós hálót Keras-ban és add értékül a `cl_model` változónak. A háló lehetőleg kövesse a hagyományos konvolúciós architektúrát, felváltva alkalmazott konvolúciós és pooling rétegekkel, majd teljesen összekötött rétegekkel a végén. A hálónak mindenképp legyen olyan köztes rétege melynek kimenetén a heatmap-ek felbontása 16x16 pixel, ugyanis erre a rétegre fogjuk építeni a szegmentáló modellünket.
#
# A konvolúciós hálós segédanyag notebookban megtalálható hálóarchitektúrát nyugodtan felhasználhatod itt is, viszont az utolsó réteg mérete és aktivációs függvénye, valamint a költségfüggvény eltérő lesz. Egyrészről, a kettőnél több kategória esetén alkalmazott multi-class klasszifikációnál szokásos aktivációs- és költségfüggvényt kell alkalmaznod.
#
# Bár a címkékhez a one-hot kódolást kézzel is elő lehet állítani, mi ezúttal ezt nem tesszük meg: a Keras tudja kezelni az eredeti kategóriacímke-tömböt is, ha a szokásos költség "sparse" változatát használjuk. Lásd: https://keras.io/losses/ (lap alja, "Note: ...")
#
# A modellt fordítsd le a `compile()` függvény segítségével!

# %%
# implement your solution BELOW

'''Ez volt a korábbi modellem mielőtt, az N feladathoz értem
cl_model = Sequential()
cl_model.add(Conv2D(20, (3,3), input_shape=(128,128,3), activation='relu', padding='same'))
cl_model.add(MaxPooling2D((2,2))) # (64,64,20)
cl_model.add(Conv2D(40, (3,3), activation='relu', padding='same'))
cl_model.add(MaxPooling2D((2,2))) # (32,32,40)
cl_model.add(Dropout(0.3))
cl_model.add(Conv2D(40, (3,3), activation='relu', padding='same'))
cl_model.add(MaxPooling2D((2,2))) # (16,16,40)
cl_model.add(Dropout(0.3))
cl_model.add(Conv2D(40, (3,3), activation='relu', padding='same'))
cl_model.add(MaxPooling2D((2,2))) # (8,8,40)
cl_model.add(Dropout(0.3))
cl_model.add(Flatten())
cl_model.add(Dense(400, activation='relu'))
cl_model.add(Dropout(0.3))
cl_model.add(Dense(100, activation='relu'))
cl_model.add(Dense(5, activation='softmax'))
'''

inputs = Input((128,128,3))
conv1 = Conv2D(20, (3,3), activation='relu', padding='same')(inputs)
pool1 = MaxPooling2D((2,2))(conv1) # (64,64,20)
conv2 = Conv2D(40, (3,3), activation='relu', padding='same')(pool1)
pool2 = MaxPooling2D((2,2))(conv2) # (32,32,40)
drop1 = Dropout(0.3)(pool2)
conv3 = Conv2D(40, (3,3), activation='relu', padding='same')(drop1)
pool3 = MaxPooling2D((2,2))(conv3) # (16,16,40)
drop2 = Dropout(0.3)(pool3)
conv4 = Conv2D(40, (3,3), activation='relu', padding='same')(drop2)
pool4 = MaxPooling2D((2,2))(conv4) # (8,8,40)
drop3 = Dropout(0.3)(pool4)
flat = Flatten()(drop3)
dense1 = Dense(400, activation='relu')(flat)
drop4 = Dropout(0.3)(dense1)
dense2 = Dense(100, activation='relu')(drop4)
dense3 = Dense(5, activation='softmax')(dense2)
cl_model = Model(inputs=inputs, outputs=dense3)

sgd_optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
cl_model.compile(optimizer=sgd_optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])


# implement your solution ABOVE

tester.test('cl_architecture', cl_model)
# Out:
# Tester: Classifier model architecture OK

# %% [markdown]
# ###**G**: Input generátorok definiálása augmentáláshoz
#
# Sajnos a néhány ezer képből álló adatbázisunkra hamar túltanulna a hálónk és nincs lehetőségünk új tanítóadatot beszerezni, így az adat-augmentálás technikájához kell fordulnunk.
# Bár megtehetnénk azt is, hogy véletlenszerűen választott transzformációkkal augmentálunk egy adatbázist a betanítás előtt és evvel az augmentált, fix méretű adatbázissal tanítunk, de ebben az esetben vagy túl sok helyet foglalna az augmentált adatbázisunk, vagy nem lenne túl változatos az, a limitált méret miatt.
#
# Egy ügyesebb megoldás generátorok/iterátorok alkalmazása a betanításhoz. A generátorokról/iterátorokról részletesebben a _"Python tutorial - Iterátorok és generátorok"_ című notebookban lehet olvasni. A Keras-ban számunkra elérhető ImageDataGenerator egyfajta, iterátort készítő osztály, ami képes olyan iterátort visszaadni, ami egy fix méretű adatbázisból véletlenszerűen generálja le mintaelemek batch-eit (kötegeit) és azokat véletlenszerűen augmentálja is az általunk megadott paraméterek szerint. A megvalósítás hatékony, hiszen míg a GPU-n betanítjuk a modellünket, párhuzamosan, a CPU szabad kapacitását az augmentálással járó számításigényes transzformációkhoz lehet felhasználni.
#
# Definiáld a `datagen` ImageDataGenerator példányt, melyet a betanítás során a tanító- és a validációs halmaz augmentálásához fogunk használni! Az alábbi augmentációkat végezze el:
#
# - Elforgatás (rotate) -30 .. +30 fokkal
# - Eltolás (shift) -25% .. + 25%-kal (a képmérethez képest, széltében és magasságában is)
# - Tükrözés (flip) vízszintesen (függőleges tengelyre)
# - A transzformációk következtében lefedetlen pixelek kitöltése: a kép ismétlésével (wrap fill_mode)
# - Skálázás (zoom) 80% .. 120%-os nagyításra
#
# Továbbá:
#
# - **G/1**: Tükrözés függőlegesen (vízszintes tengelyre), színcsatornák fényerejének független skálázása (channel shift) -20% .. +20% közt.
# - **G/2**: Nyírás (shear) -20% .. +20% közt, színcsatornák fényerejének független skálázása (channel shift)  -10% .. +10% közt.
# - **G/3**: Tükrözés függőlegesen (vízszintes tengelyre), nyírás (shear) -10% .. +10% közt.
#
# Az ImageDataGenerator példány `flow()` tagfüggvénye készíti el magát az iterátort, amiből kinyerhetjük a véletlenszerűen választott, augmentált input-output batch-eket. Ennek, paraméterül kell megadni az iterációhoz használt input és output tömböket. Készítsd el a tanító- és validáló- iterátorokat ilyen módon és add értékül őket a `train_generator` és `val_generator` nevű változóknak!

# %%
# implement your solution BELOW

datagen_params = {'rotation_range': 30,
    'width_shift_range': 0.25,             
    'height_shift_range': 0.25,
    'horizontal_flip': True,
    'vertical_flip': True,
    'zoom_range': 0.2,
    'shear_range': 0.1,
    'fill_mode': 'wrap'
    }

datagen = ImageDataGenerator(**datagen_params)
train_generator = datagen.flow(x_train, y_train, batch_size=64)
val_generator = datagen.flow(x_val, y_val, batch_size=64)


# implement your solution ABOVE

tester.test('cl_datagen', datagen, train_generator, val_generator)
# Out:
# Tester: Classifier data generators OK

# %% [markdown]
# ###**H**: A háló betanítása klasszifikációs feladatra
#
# Tanítsd be a `cl_model` konvolúciós neuronhálót a klasszifikációs feladatra!
#
# Használd a Keras Model `fit_generator()` tagfüggvényét a tanító- és validációs iterátorokkal a betanításhoz! A tanítás végeztével mérd le a modell pontosságát (accuracy) a teszthalmazon! Ehhez használd a Model `evaluate()` függvényét: ez kiszámolja az accuracy-t, ha előzőleg a megfelelő metrikát megadtad a Model lefordításakor.
#
# **Megjegyzés**: Érdemes lehet `ModelCheckpoint` callback-et használni a betanítás közben a súlyok időnkénti kimentésére. A checkpoint-ot használva, azután már nem szükséges a hálót újból betanítani a notebook további részével való munkához, a korábbi tanítás súlyai betölthetők.
#
# A mentett checkpoint fájlokat akár le is lehet tölteni saját gépre: így, ha megszakítod a munkát és később folytatod azt, abban az esetben, ha törlődne a futtatókörnyezet tárhelyéről a checkpoint, feltöltheted újból a lementett checkpoint fájlokat, ezáltal nem kell többször újra betanítod a klasszifikációs modellt. Ennek mikéntjéről a _"Képek bináris klasszifikációja konvolúciós neuronhálóval"_ című segédanyag notebookban olvashatsz.

# %%
# implement your solution BELOW

model_checkpoint_folder = './chkpts_annbsc_cnn_multicl'
LOAD_MODEL_FROM_CHECKPOINT = True
checkpoint_name_to_load = 'cp-0040.ckpt'

if LOAD_MODEL_FROM_CHECKPOINT and os.path.isdir(model_checkpoint_folder):
    
    checkpoint_path = os.path.join(model_checkpoint_folder, checkpoint_name_to_load)
    cl_model.load_weights(checkpoint_path)
    print("Model loaded from checkpoint:", checkpoint_path)

else:
    # initialize weights from scratch, train weights
    print("Checkpoint folder was not found. Training classifier...")

    model_chkpt = tf.keras.callbacks.ModelCheckpoint(os.path.join(model_checkpoint_folder, 'cp-{epoch:04d}.ckpt'), verbose=1,\
                                  save_weights_only=True, period=20)
    earlystopping_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss',\
                                         patience=20, restore_best_weights=True)
    
    history = cl_model.fit_generator(generator=train_generator, validation_data=val_generator,
                    steps_per_epoch=30, validation_steps=15, epochs=100, verbose=1,
                    callbacks=[earlystopping_callback,model_chkpt])


    tr_losses = history.history['loss']
    val_losses = history.history['val_loss']

    tr_accs = history.history['accuracy']
    val_accs = history.history['val_accuracy']

    plt.clf()
    plt.plot(tr_losses, label="J_train")
    plt.plot(val_losses, label="J_val")
    #y_lim_top = np.maximum(np.amax(val_losses[2:]), np.amax(tr_losses[2:]))*1.5
    plt.ylim((0.8, 1.8))
    plt.xlabel("Number of epochs")
    plt.ylabel("Cost (J)")
    plt.legend()
    plt.show();

    plt.clf()
    plt.plot(tr_accs, label="acc_train")
    plt.plot(val_accs, label="acc_val")
    plt.ylim((0.2, 1.))
    plt.xlabel("Number of epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show();

test_ce, test_acc = cl_model.evaluate(x_test,y_test,verbose=0)
    


# implement your solution ABOVE

tester.test('cl_training', test_acc)
# Out:
# Checkpoint folder was not found. Training classifier...
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:From <ipython-input-12-33d49f79343f>:22: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 30/30 [==============================] - ETA: 0s - loss: 1.5892 - accuracy: 0.2409WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 15 batches). You may need to use the repeat() function when building your dataset.
# 30/30 [==============================] - 12s 383ms/step - loss: 1.5892 - accuracy: 0.2409 - val_loss: 1.5329 - val_accuracy: 0.3013
# Epoch 2/100
# 30/30 [==============================] - ETA: 0s - loss: 1.5280 - accuracy: 0.2890WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 15 batches). You may need to use the repeat() function when building your dataset.
# 30/30 [==============================] - 11s 370ms/step - loss: 1.5280 - accuracy: 0.2890 - val_loss: 1.5169 - val_accuracy: 0.3125
# Epoch 3/100
# 30/30 [==============================] - ETA: 0s - loss: 1.5238 - accuracy: 0.2832WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 15 batches). You may need to use the repeat() function when building your dataset.
# 30/30 [==============================] - 11s 373ms/step - loss: 1.5238 - accuracy: 0.2832 - val_loss: 1.5077 - val_accuracy: 0.3050
# Epoch 4/100
# 30/30 [==============================] - ETA: 0s - loss: 1.5151 - accuracy: 0.3086WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 15 batches). You may need to use the repeat() function when building your dataset.
# 30/30 [==============================] - 11s 372ms/step - loss: 1.5151 - accuracy: 0.3086 - val_loss: 1.5026 - val_accuracy: 0.3038
# Epoch 5/100
# 30/30 [==============================] - ETA: 0s - loss: 1.5114 - accuracy: 0.2948WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 15 batches). You may need to use the repeat() function when building your dataset.
# 30/30 [==============================] - 11s
ARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 15 batches). You may need to use the repeat() function when building your dataset.
# 30/30 [==============================] - 11s 374ms/step - loss: 1.2779 - accuracy: 0.4463 - val_loss: 1.2489 - val_accuracy: 0.4850
# Epoch 96/100
# 30/30 [==============================] - ETA: 0s - loss: 1.2653 - accuracy: 0.4352WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 15 batches). You may need to use the repeat() function when building your dataset.
# 30/30 [==============================] - 11s 363ms/step - loss: 1.2653 - accuracy: 0.4352 - val_loss: 1.2570 - val_accuracy: 0.4550
# Epoch 97/100
# 30/30 [==============================] - ETA: 0s - loss: 1.2617 - accuracy: 0.4436WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 15 batches). You may need to use the repeat() function when building your dataset.
# 30/30 [==============================] - 11s 363ms/step - loss: 1.2617 - accuracy: 0.4436 - val_loss: 1.2310 - val_accuracy: 0.4613
# Epoch 98/100
# 30/30 [==============================] - ETA: 0s - loss: 1.2751 - accuracy: 0.4276WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 15 batches). You may need to use the repeat() function when building your dataset.
# 30/30 [==============================] - 11s 364ms/step - loss: 1.2751 - accuracy: 0.4276 - val_loss: 1.3036 - val_accuracy: 0.4600
# Epoch 99/100
# 30/30 [==============================] - ETA: 0s - loss: 1.2431 - accuracy: 0.4685WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 15 batches). You may need to use the repeat() function when building your dataset.
# 30/30 [==============================] - 11s 360ms/step - loss: 1.2431 - accuracy: 0.4685 - val_loss: 1.2661 - val_accuracy: 0.4638
# Epoch 100/100
# 30/30 [==============================] - ETA: 0s - loss: 1.2479 - accuracy: 0.4606WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 15 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 00100: saving model to ./chkpts_annbsc_cnn_multicl/cp-0100.ckpt
# 30/30 [==============================] - 11s 363ms/step - loss: 1.2479 - accuracy: 0.4606 - val_loss: 1.2427 - val_accuracy: 0.4500
# Tester: Classifier training OK

# %% [markdown]
# ###**I**: Teszthalmaz predikciók kirajzolása/kiírása
#
# Rajzolj ki néhány **véletlenszerűen választott** képet a teszthalmazból és írasd ki a betanított modell által becsült legvalószínűbb kategóriacímke nevét!

# %%
# implement your solution BELOW

def NumToCatName(num):
    pred_cat_name = ""
    if num == 0:
      pred_cat_name = 'other'
    elif num == 1:
      pred_cat_name = 'cat'
    elif num == 2:
      pred_cat_name = 'dog'
    elif num == 3:
      pred_cat_name = 'horse'
    else:
      pred_cat_name = 'sheep'
    return pred_cat_name

#y_pred_test = cl_model.predict(x_test, verbose=0)
sample_idxs = np.random.choice(x_test.shape[0], size=12)
y_pred_test = cl_model.predict(x_test[sample_idxs], verbose=0)
predicted_categories = np.argmax(y_pred_test, axis=1) #Kiválasztjuk a legjobb becslést, ami a maximum


fig, axs = plt.subplots(2, 6)
fig.set_figheight(6)
fig.set_figwidth(14)
for plot_idx in range(12):
    axs[plot_idx//6, plot_idx%6].imshow(x_test[sample_idxs[plot_idx]]*0.5 + 0.5)
    axs[plot_idx//6, plot_idx%6].axis('off')
    axs[plot_idx//6, plot_idx%6].set_title(NumToCatName(predicted_categories[plot_idx]))


# implement your solution ABOVE

# %% [markdown]
# ###**J**: Szegmentációhoz felhasznált kategóriához tartozó képek összegyűjtése és maszkok előállítása
#
# Mint már korábban említve lett, a szegmentációs feladathoz a klasszifikációban nem használt kategóriára fogunk tanítani. Például, ha a **B/1.** részfeladatot kaptad és így a klasszifikációs kategóriáid a [{'aeroplane', 'bird', 'boat', 'bus', 'car'}, 'cat', 'dog', 'horse', 'sheep'] voltak, akkor a szegmentációhoz csak a kimaradt 'cow' kategória elemeit kell kiválogatnod: tehenek szegmentálására kell betanítanod majd. **B/2.** esetén a kimaradt kategória a 'horse', **B/3.** esetén a 'sheep'.
#
# Szegmentáláshoz az `arr_seg_data` képeket tartalmazó tömb és az `arr_seg_labs` hozzá tartozó pixelszintű annotációs tömb egy részhalmazával dolgozunk tovább. Kizárólag azokat a képeket fogjuk felhasználni a betanításhoz, ahol a képekhez tartozó pixelszintű címkéken legalább egy pixel erejéig megjelenik a szegmentáláshoz választott háziállat kategóriánk. Azaz, például a **B/1.** opció esetén, azokat a képeket/címkéket tartjuk meg, ahol a címkében legalább egy pixel azonosítója egyezik a 'cow' kategória eredeti azonosítójával. Ne feledd, az eredeti 10 kategória azonosítóit itt 1-től kezdve sorolták fel, nem nullától kezdve!
#
# Állítsd elő az `xs_seg` és `ys_big_seg` tömböket! Az `xs_seg` tömb alakja (n_chosen_cat_seg_imgs, size_y=128, size_x=128, n_channels=3) és azokat a képeket tartalmazza, ahol a szegmentáláshoz választott kategória azonosítója legalább egy pixel erejéig megjelenik a képekhez tartozó pixelszintű maszkokon.
# Az `ys_big_seg` tömb alakja (n_chosen_cat_seg_imgs, size_y=128, size_x=128) és kizárólag 0 és 1 értékeket tartalmaz. Ott lesznek benne 1 értékű pixelek, ahol az eredeti pixelszintű annotációkon a szegmentáláshoz választott kategória azonosítója található. Minden más pixel értéke 0 lesz. Azaz, röviden, bináris maszkokat állítunk elő "választott háziállat" és "háttér" kategóriákkal.

# %%
# implement your solution BELOW

CATEGORY_NEW_IDX_COW = 7

ys_big_seg = np.zeros((arr_seg_labs.shape), dtype=np.int32)
cows_mask = arr_seg_labs[:,:,:] == CATEGORY_NEW_IDX_COW
ys_big_seg[cows_mask] = 1
cows_indxs = np.nonzero(ys_big_seg)[0]
cows_indxs = np.unique(cows_indxs)
ys_big_seg = ys_big_seg[cows_indxs]
xs_seg = arr_seg_data [cows_indxs]

# implement your solution ABOVE

print("Shapes of selected image and mask arrays:", xs_seg.shape, ys_big_seg.shape)

tester.test('seg_dataset_creation', xs_seg, ys_big_seg)
# Out:
# Shapes of selected image and mask arrays: (135, 128, 128, 3) (135, 128, 128)
# Tester: Segmentation dataset OK

# %% [markdown]
# ###**K**: A szegmentáláshoz címkeként használt maszkok leskálázása
#
# Ahhoz, hogy csökkentsük a szegmentáció betanításának számításigényét, leskálázzuk a maszkokat 128x128-ról 16x16-os felbontásra. A leskálázás követendő technikáját a számodra kiosztott részfeladat határozza meg:
#
# - **K/1.**: Leskálázás blokkonkénti átlagolással. Azaz, ha egy pixellé leskálázandó 8x8-as blokkban pl. 27 pixel világos (1) és 37 pixel sötét (0), akkor a blokkból leskálázással kapott pixel értéke 27./64. **Update**: Nem kell pontosan ilyen értékeket kapni, de jussunk körülbelül hasonló köztes értékeket! OpenCV resize() függvénye is használható megfelelő interpoláció paraméterrel.
# - **K/2.**: Leskálázás bináris maszkká. Csupa világos (1) és csupa sötét (0) blokkokat világos és sötét pixelekké alakítunk. Minden olyan blokkot, ahol vegyesen találhatók világos és sötét pixelek, tetszőlegesen világos, vagy sötét pixellé skálázunk le, de nem köztes értékre.
#
# Készítsd el az `ys_big_seg` tömb 16x16 felbontásra leskálázott változatát `ys_seg` néven! A betanításhoz szükséges, hogy a maszk tömb, az input tömbhöz hasonlóan 4 dimenziós legyen, alakja (n_chosen_cat_seg_imgs, 16, 16, 1) lesz.

# %%
# implement your solution BELOW

# Forrás kis módosítással: https://stackoverflow.com/questions/16856788/slice-2d-array-into-smaller-2d-arrays
def blockshaped(arr, nrows, ncols):   
    """
    Return an array of shape (n, nrows, ncols) where
    n * nrows * ncols = arr.size

    If arr is a 2D array, the returned array should look like n subblocks with
    each subblock preserving the "physical" layout of arr.
    """
    n, h, w = arr.shape
    assert h % nrows == 0, "{} rows is not evenly divisble by {}".format(h, nrows)
    assert w % ncols == 0, "{} cols is not evenly divisble by {}".format(w, ncols)
    return (arr.reshape(n, h//nrows, nrows, -1, ncols)
               .swapaxes(2,3)
               .reshape(-1, h//nrows, w//ncols, nrows, ncols))

ys_seg = blockshaped(ys_big_seg, 8, 8)
ys_seg = np.asarray(ys_seg, dtype=np.float32)
ys_seg  = np.average(ys_seg, axis=(3,4))
ys_seg= np.reshape(ys_seg,(135, 16, 16, 1))

# implement your solution ABOVE

tester.test('seg_mask_downscale', ys_seg)
# Out:
# Tester: Segmentation mask downscale OK

# %% [markdown]
# ###**L**: Normalizálás és felbontás tanító-, validációs- és teszthalmazra
#
# - Konvertáljuk az `xs_seg` elemeit a D) feladathoz hasonlóan `float32` típusra és a [-1,1] intervallumra.
# - Bontsuk fel tanító-, validációs- és teszthalmazra a két tömböt. Használjunk 60%/20%/20%-os felosztást. Állítsuk elő így az `x_seg_train`, `x_seg_val`, `x_seg_test` inputokat (képeket) és `y_seg_train`, `y_seg_val`, `y_seg_test` címkéket (maszkokat) tartalmazó tömböket!

# %%
# implement your solution BELOW

val_offset = int(xs_seg.shape[0]*0.6)
test_offset = int(xs_seg.shape[0]*0.8)

xs_seg_train_unnormed = xs_seg [:val_offset]
xs_seg_val_unnormed = xs_seg [val_offset:test_offset]
xs_seg_test_unnormed = xs_seg [test_offset:]
ys_seg_train_unnormed = ys_seg [:val_offset]
ys_seg_val_unnormed = ys_seg [val_offset:test_offset]
ys_seg_test_unnormed = ys_seg [test_offset:]

x_seg_train = xs_seg_train_unnormed.astype(np.float32)/127.5 - 1.
x_seg_val = xs_seg_val_unnormed.astype(np.float32)/127.5 - 1.
x_seg_test  = xs_seg_test_unnormed.astype(np.float32)/127.5 - 1.
y_seg_train = ys_seg_train_unnormed.astype(np.float32)
y_seg_val = ys_seg_val_unnormed.astype(np.float32)
y_seg_test  = ys_seg_test_unnormed.astype(np.float32)


# implement your solution ABOVE

tester.test('seg_dataset_split', x_seg_train, x_seg_val, x_seg_test, y_seg_train, y_seg_val, y_seg_test)
# Out:
# Tester: Segmentation dataset split OK

# %% [markdown]
# ###**M**: Véletlen választott kép-maszk párok kirajzolása
#
# Ellenőrizd le, hogy megfelelő volt-e a képek és maszkok előfeldolgozása! Rajzolj ki néhány véletlenszerűen választott képet az `x_seg_train`, `x_seg_val`, `x_seg_test` tömbök egyikéből és rajzold ki alá/mellé/fölé a hozzá tartozó leskálázott maszkokat is!

# %%
# implement your solution BELOW

selected = np.random.choice(len(x_seg_train), 5)

plt.figure(figsize=(14, 6))
for i, ind in enumerate(selected):
  plt.subplot(2, 5, i+1)
  plt.imshow(((x_seg_train[ind]+1)*127.5).astype(np.uint8))
  plt.axis('off')
  plt.subplot(2, 5, i+6)
  plt.imshow(y_seg_train[ind].reshape((16, 16,)))
  plt.axis('off')



# implement your solution ABOVE

# %% [markdown]
# ###**N**: FCN (Fully-Convolutional Network) definiálása szegmentációhoz
#
# Definiáld a `seg_model` FCN típusú neuronhálót! A modell nem kell, hogy bonyolult legyen. Nem tartalmazhat teljesen összekötött rétegeket. A háló inputja legyen a klasszifikációra tanított konvolúciós háló azon rétegének kimenete, ahol a heatmap felbontása egyezik a leskálázott maszkok méretével, azaz 16x16! A háló output felbontása is legyen ugyanekkora, utolsó rétegének aktivációs függvénye a bináris klasszifikációhoz használt függvény lehet, hiszen a bináris szegmentációval lényegében pixelenkénti bináris klasszifikációt hajtunk végre. A költségfüggvény is ennek megfelelő kell, hogy legyen.
#
# Egy példa egyszerű FCN hálóra (az előtanított hálóban levő rétegeket nem felsorolva):
# - konv. réteg 3x3-as filterrel, 40 filter, ReLU
# - konv. réteg 3x3-as filterrel, 20 filter, ReLU
# - dropout p=0.3
# - konv. réteg 3x3-as filterrel, 1 filter, bin. klasszifikációhoz használt aktivációs fv.

# %%
# implement your solution BELOW

'''Korábbi model, de ez nem használná fel az előtanítást
inputs = Input((128,128,3)) 

#seg_model = Sequential()
#seg_model.add(Conv2D(40, 3, input_shape=(16,16,3), activation='relu', padding='same'))
#seg_model.add(Conv2D(20, 3, activation='relu', padding='same'))
#seg_model.add(Dropout(0.3))
#seg_model.add(Conv2D(1, 3, activation='sigmoid', padding='same'))
#seg_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#seg_model.summary()
'''

seg_inputs = conv4
conv_seg1 = Conv2D(40, 3, activation='relu', padding='same')(seg_inputs)
conv_seg2 = Conv2D(20, 3, activation='relu', padding='same')(conv_seg1)
drop_seg = Dropout(0.3)(conv_seg2)
conv_seg3 = Conv2D(1, 3, activation='sigmoid', padding='same')(drop_seg)
seg_model = Model(inputs=inputs, outputs=conv_seg3)
seg_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['MeanSquaredError'])
seg_model.summary()


# implement your solution ABOVE

tester.test('seg_architecture', seg_model)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 128, 20)      560
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 20)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 40)        7240
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 40)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 40)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 40)        14440
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 40)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 40)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 40)        14440
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 40)        14440
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 20)        7220
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 16, 20)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 1)         181
# =================================================================
# Total params: 58,521
# Trainable params: 58,521
# Non-trainable params: 0
# _________________________________________________________________
# Tester: Segmentation model architecture OK

# %% [markdown]
# ###**O**: Input generátorok definiálása augmentáláshoz
#
# Definiáld a `seg_datagen` ImageDataGenerator példányt, melyet a betanítás során a tanító- és a validációs halmaz augmentálásához fogunk használni! Az alábbi augmentációkat végezzék el a példányok:
#
# - Elforgatás (rotate) -90 .. +90 fokkal
# - Tükrözés (flip) vízszintesen (függőleges tengelyre)
# - A transzformációk következtében lefedetlen pixelek kitöltése: konstans fekete színnel (constant fill_mode)
#
# Továbbá:
#
# - **O/1**: Tükrözés függőlegesen (vízszintes tengelyre), skálázás (zoom) 60% .. 140%-os nagyításra.
# - **O/2**: Nyírás (shear) -10% .. +10% közt,  skálázás (zoom) 80% .. 120%-os nagyításra.
# - **O/3**: Tükrözés függőlegesen (vízszintes tengelyre), nyírás (shear) -20% .. +20% közt.
#
# Ahogy a **G.** feladatban is, az ImageDataGenerator példány `flow()` tagfüggvénye készíti el magát az iterátort, amiből kinyerhetjük a véletlenszerűen választott, augmentált input-output batch-eket. Ebben az esetben azonban az output-unk is kép, amit azonos módon szeretnénk augmentálni, mint az inputot. Mivel a `flow()` az augmentálandó kép formátumú adatot csak az inputon várja, külön kell meghívnunk az inputra és az outputra: mind az inputot, mind az outputot inputként adjuk be, címkék megadása nélkül. Azonban, így különböző módon augmentálná az input-ot és az output-ot a két iterátor, a képekhez már nem illeszkedne a maszk. Ezért, a `seed` paramétert kell használnunk, méghozzá úgy, hogy az input és az output iterálására külön meghívott `flow()` függvények ugyanazt a `seed` paramétert kapják meg, így az előállított két iterátor pontosan ugyanazokat az augmentálási műveleteket fogja végrehajtani.
#
# A kapott két iterátort ezután össze kell fűznünk, pl. a `zip()` beépített függvény segítségével, hogy az input-output kötegek egy-egy tuple-be kerüljenek be, ahogy azt a Keras Model `fit_generator()` várja.
#
# Állítsd elő ilyen módon a `train_seg_generator` és `val_seg_generator` iterátorokat! A két iterátor előállításhoz, tehát összesen négy `flow()` hívás kell, a tanító- és validációs iterátor párokhoz különböző seed-et illene megadni.

# %%
# implement your solution BELOW

datagen_seg_params = {'rotation_range': 90,
    'horizontal_flip': True,
    'vertical_flip': True,
    'shear_range': 0.2,
    'fill_mode': 'constant'
    }

seg_datagen = ImageDataGenerator(**datagen_seg_params)
train_x_generator = seg_datagen.flow(x_seg_train, batch_size=64, seed =1)
train_y_generator = seg_datagen.flow(y_seg_train, batch_size=64, seed =1)
val_x_generator = seg_datagen.flow(x_seg_val, batch_size=64, seed= 2)
val_y_generator = seg_datagen.flow(y_seg_val, batch_size=64, seed= 2)

train_seg_generator = zip(train_x_generator,train_y_generator)
val_seg_generator = zip(val_x_generator,val_y_generator)

# implement your solution ABOVE

tester.test('seg_datagen', seg_datagen, train_seg_generator, val_seg_generator)
# Out:
# Tester: Segmentation data generators OK

# %% [markdown]
# ###**P**: A háló betanítása szegmentációs feladatra
#
# Tanítsd be a `seg_model` FCN típusú neuronhálót a bináris szegmentációs feladatra!
#
# Használd a Keras Model `fit_generator()` tagfüggvényét a tanító- és validációs iterátorokkal a betanításhoz! A tanítás végeztével mérd le a modell hibáját a MAE metrikával a teszthalmazon! Ehhez használd a Model `evaluate()` függvényét: ez kiszámolja a MAE-t, ha előzőleg a megfelelő metrikát megadtad a Model lefordításakor.
#
# **Megjegyzés**: Ez a háló egy percen belül betanítható, így nincs szükség model checkpointokra feltétlenül.

# %%
# implement your solution BELOW

batch_size = 64
early_stopping = EarlyStopping(patience=10)
history = seg_model.fit_generator(train_seg_generator, 
                              steps_per_epoch=len(x_train) // batch_size, 
                              validation_data=val_seg_generator, 
                              validation_steps=max(1, len(x_val) // batch_size),
                              verbose=1, epochs=30, callbacks=[early_stopping])

test_ce, test_mae = seg_model.evaluate(x_seg_test, y_seg_test, verbose=0)

# implement your solution ABOVE

tester.test('seg_training', test_mae)
# Out:
# Epoch 1/10
# 37/37 [==============================] - 7s 194ms/step - loss: 0.2575 - mean_squared_error: 0.0446 - val_loss: 0.3922 - val_mean_squared_error: 0.0860
# Epoch 2/10
# 37/37 [==============================] - 7s 199ms/step - loss: 0.2551 - mean_squared_error: 0.0438 - val_loss: 0.4403 - val_mean_squared_error: 0.1008
# Epoch 3/10
# 37/37 [==============================] - 7s 195ms/step - loss: 0.2650 - mean_squared_error: 0.0462 - val_loss: 0.4163 - val_mean_squared_error: 0.0926
# Epoch 4/10
# 37/37 [==============================] - 7s 199ms/step - loss: 0.2590 - mean_squared_error: 0.0454 - val_loss: 0.4317 - val_mean_squared_error: 0.0962
# Epoch 5/10
# 37/37 [==============================] - 7s 194ms/step - loss: 0.2630 - mean_squared_error: 0.0453 - val_loss: 0.3967 - val_mean_squared_error: 0.0883
# Epoch 6/10
# 37/37 [==============================] - 7s 198ms/step - loss: 0.2567 - mean_squared_error: 0.0442 - val_loss: 0.4305 - val_mean_squared_error: 0.0957
# Epoch 7/10
# 37/37 [==============================] - 7s 196ms/step - loss: 0.2614 - mean_squared_error: 0.0452 - val_loss: 0.4006 - val_mean_squared_error: 0.0884
# Epoch 8/10
# 37/37 [==============================] - 7s 197ms/step - loss: 0.2588 - mean_squared_error: 0.0450 - val_loss: 0.4631 - val_mean_squared_error: 0.1038
# Epoch 9/10
# 37/37 [==============================] - 7s 197ms/step - loss: 0.2683 - mean_squared_error: 0.0467 - val_loss: 0.4066 - val_mean_squared_error: 0.0902
# Epoch 10/10
# 37/37 [==============================] - 8s 203ms/step - loss: 0.2484 - mean_squared_error: 0.0415 - val_loss: 0.4552 - val_mean_squared_error: 0.1011
# Tester: Segmentation training OK

# %% [markdown]
# ###**Q**: Teszthalmaz szegmentációs predikciók kirajzolása
#
# Rajzolj ki néhány **véletlenszerűen választott** képet a teszthalmazból és rajzold ki a hozzájuk becsült maszkokat!

# %%
# implement your solution BELOW

selected = np.random.choice(len(x_seg_test), 5)
y_pred_seg_test = seg_model.predict(x_seg_test[selected], verbose=0)

plt.figure(figsize=(14, 6))
for i, ind in enumerate(selected):
  plt.subplot(2, 5, i+1)
  plt.imshow(((x_seg_test[ind]+1)*127.5).astype(np.uint8))
  plt.axis('off')
  plt.subplot(2, 5, i+6)
  plt.imshow(y_seg_train[ind].reshape((16, 16,)))
  plt.axis('off')

# implement your solution ABOVE

'''
sample_idxs = np.random.choice(x_test.shape[0], size=12)
y_pred_test = cl_model.predict(x_test[sample_idxs], verbose=0)
predicted_categories = np.argmax(y_pred_test, axis=1) #Kiválasztjuk a legjobb becslést, ami a maximum


fig, axs = plt.subplots(2, 6)
fig.set_figheight(6)
fig.set_figwidth(14)
for plot_idx in range(12):
    axs[plot_idx//6, plot_idx%6].imshow(x_test[sample_idxs[plot_idx]]*0.5 + 0.5)
    axs[plot_idx//6, plot_idx%6].axis('off')
    axs[plot_idx//6, plot_idx%6].set_title(NumToCatName(predicted_categories[plot_idx]))
'''

tester.print_all_tests_successful()
# Out:
# Tester: All tests were successful.
